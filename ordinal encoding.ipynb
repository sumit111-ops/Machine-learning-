# %% [markdown]
# # 🏷️ Encoding in Machine Learning
#
# This notebook demonstrates **Label Encoding** and **Ordinal Encoding** step-by-step using Python and Scikit-learn.

# %% [markdown]
# ## 1. Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2. Create Sample Dataset

# %%
df = pd.DataFrame({
    'Gender': ['Male', 'Female', 'Female', 'Male', 'Male'],
    'Size': ['Small', 'Medium', 'Large', 'Medium', 'Small']
})

df
# Out:
#    Gender    Size
# 0    Male   Small
# 1  Female  Medium
# 2  Female   Large
# 3    Male  Medium
# 4    Male   Small

# %% [markdown]
# ## 3. Label Encoding using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['Gender_encoded_LE'] = le.fit_transform(df['Gender'])

df
# Out:
#    Gender    Size  Gender_encoded_LE
# 0    Male   Small                  1
# 1  Female  Medium                  0
# 2  Female   Large                  0
# 3    Male  Medium                  1
# 4    Male   Small                  1

# %% [markdown]
# ## 4. Label Encoding using Manual Mapping (Best Practice)

# %%
df['Gender_encoded_manual'] = df['Gender'].map({'Male': 1, 'Female': 0})

df
# Out:
#    Gender    Size  Gender_encoded_LE  Gender_encoded_manual
# 0    Male   Small                  1                      1
# 1  Female  Medium                  0                      0
# 2  Female   Large                  0                      0
# 3    Male  Medium                  1                      1
# 4    Male   Small                  1                      1

# %% [markdown]
# ## 5. Ordinal Encoding using Manual Mapping

# %%
df['Size_encoded_manual'] = df['Size'].map({
    'Small': 0,
    'Medium': 1,
    'Large': 2
})

df
# Out:
#    Gender    Size  Gender_encoded_LE  Gender_encoded_manual  \
# 0    Male   Small                  1                      1
# 1  Female  Medium                  0                      0
# 2  Female   Large                  0                      0
# 3    Male  Medium                  1                      1
# 4    Male   Small                  1                      1
#
#    Size_encoded_manual
# 0                    0
# 1                    1
# 2                    2
# 3                    1
# 4                    0

# %% [markdown]
# ## 6. Ordinal Encoding using Sklearn OrdinalEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder

oe = OrdinalEncoder(categories=[['Small', 'Medium', 'Large']])
df[['Size_encoded_sklearn']] = oe.fit_transform(df[['Size']])

df
# Out:
#    Gender    Size  Gender_encoded_LE  Gender_encoded_manual  \
# 0    Male   Small                  1                      1
# 1  Female  Medium                  0                      0
# 2  Female   Large                  0                      0
# 3    Male  Medium                  1                      1
# 4    Male   Small                  1                      1
#
#    Size_encoded_manual  Size_encoded_sklearn
# 0                    0                   0.0
# 1                    1                   1.0
# 2                    2                   2.0
# 3                    1                   1.0
# 4                    0                   0.0

# %% [markdown]
# ## 7. Safe Encoding with Train-Test Split (Avoid Data Leakage)

# %%
from sklearn.model_selection import train_test_split

X = df[['Size']]
X_train, X_test = train_test_split(X, test_size=0.3, random_state=0)

oe = OrdinalEncoder(categories=[['Small', 'Medium', 'Large']])
oe.fit(X_train)

X_train_encoded = oe.transform(X_train)
X_test_encoded = oe.transform(X_test)

X_train_encoded, X_test_encoded
# Out:
# (array([[1.],
#         [1.],
#         [0.]]),
#  array([[2.],
#         [0.]]))

# %% [markdown]
# 8. Summary
#
# - Label Encoding is used for binary or simple categorical data.
# - Ordinal Encoding is used when categories have a meaningful order.
# - Always fit encoders on training data to avoid data leakage.
